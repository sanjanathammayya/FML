# %% [markdown]
# linearRegression
# to get the relationalship b/w 2 variables (IDV and DV)
# don't use standart scalar

# %%
#linearRegression
#to get the relationalship b/w 2 variables (IDV and DV)
#don't use standart scalar

# %%
# Importing the libraries
import numpy as np #numerical
import matplotlib.pyplot as plt # plotting a graph
import pandas as pd #to read the csv file, help in data manupalation

# %%
#importing dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#importing dataset
import pandas as pd
data =pd.read_csv("drive/My Drive/Colab Notebooks FML/Datasets/income_data.csv")
dataset=data
dataset
# salry depenent and year of exp is independent
# Out:
#      Unnamed: 0    income  happiness
# 0             1  3.862647   2.314489
# 1             2  4.979381   3.433490
# 2             3  4.923957   4.599373
# 3             4  3.214372   2.791114
# 4             5  7.196409   5.596398
# ..          ...       ...        ...
# 493         494  5.249209   4.568705
# 494         495  3.471799   2.535002
# 495         496  6.087610   4.397451
# 496         497  3.440847   2.070664
# 497         498  4.530545   3.710193
#
# [498 rows x 3 columns]

# %%
#split the data into dependenet and independednt variables
#split independent variables
#dataset
X=dataset.iloc[:,:1].values
#X # X-IDV experience
y=dataset.iloc[:,-1].values
#y # y=DV salary
dataset
# Out:
#      Unnamed: 0    income  happiness
# 0             1  3.862647   2.314489
# 1             2  4.979381   3.433490
# 2             3  4.923957   4.599373
# 3             4  3.214372   2.791114
# 4             5  7.196409   5.596398
# ..          ...       ...        ...
# 493         494  5.249209   4.568705
# 494         495  3.471799   2.535002
# 495         496  6.087610   4.397451
# 496         497  3.440847   2.070664
# 497         498  4.530545   3.710193
#
# [498 rows x 3 columns]

# %%
#split the data into Training set and Test set ----row split/datapoint
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=1/3.0,random_state=0) # if random state is to get the acuurate result/constant result
y_test
# Out:
# array([1.77593255, 1.87714704, 2.46576113, 1.56035538, 0.8987328 ,
#        2.89858314, 5.3139569 , 4.75416839, 5.13240147, 4.68281699,
#        3.31379652, 6.18694561, 5.32350739, 4.2452156 , 4.48670367,
#        2.19759212, 5.58838934, 3.64088397, 4.00081918, 5.01057743,
#        2.57951651, 2.48162387, 4.79332516, 1.67239058, 3.75265949,
#        4.70820299, 2.54652459, 1.35331734, 2.89044742, 3.58138104,
#        4.32466038, 4.13077827, 2.39322812, 2.76911813, 5.36244826,
#        5.3672361 , 0.73163629, 1.79175357, 3.06760945, 4.20947057,
#        1.46061633, 4.08763118, 2.15573363, 4.03086494, 3.04079729,
#        3.43348976, 5.71380229, 2.99420428, 3.23331375, 1.89355686,
#        3.15636744, 2.4083799 , 2.26039569, 1.84367577, 2.94753147,
#        5.9518141 , 2.73496006, 3.02072445, 1.62526839, 3.03149707,
#        5.03400379, 2.24674571, 2.51740088, 4.21605759, 3.31760678,
#        2.00392609, 3.17540615, 5.74373608, 4.21269734, 5.06874788,
# ...

# %%
# #split the data into Training set and Test set ----row split/datapoint
# from sklearn.model_selection import train_test_split
# X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=1/3.0) # if random state is to select
# y_test

# %%
#split the data into Training set and Test set ----row split/datapoint
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=1/3,random_state=0) # if random state is to select
X_test
# Out:
# array([[ 91],
#        [255],
#        [284],
#        [444],
#        [337],
#        [ 16],
#        [317],
#        [488],
#        [160],
#        [154],
#        [242],
#        [251],
#        [427],
#        [290],
#        [172],
#        [328],
#        [467],
#        [354],
#        [155],
#        [ 38],
#        [206],
#        [365],
#        [241],
#        [109],
#        [ 46],
#        [437],
#        [ 22],
#        [366],
#        [ 97],
#        [234],
#        [387],
#        [119],
#        [125],
#        [192],
#        [373],
#        [358],
#        [312],
#        [448],
#        [352],
#        [239],
#        [323],
#        [ 47],
#        [402],
#        [222],
#        [ 77],
#        [  2],
#        [214],
#        [468],
#        [417],
#        [103],
#        [362],
#        [171],
#        [391],
#        [145],
#        [133],
#        [ 13],
#        [327],
#        [174],
#        [225],
#        [341],
#        [ 79],
#        [277],
# ...

# %%
# #split the data into Training set and Test set ----row split/datapoint
# from sklearn.model_selection import train_test_split
# X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=1/3.0) # if random state is to select
# X_test
# Out:
# array([[2.9],
#        [6. ],
#        [5.3],
#        [4.1],
#        [3.2],
#        [9. ],
#        [3.2],
#        [4.5],
#        [8.7],
#        [1.5]])

# %%
#Fitting Simple LR to the Training set
from sklearn.linear_model import LinearRegression # when we give fit it wiull train the model
regressor=LinearRegression() # regressor object for LR
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# predicting the test set results
y_pred=regressor.predict(X_test) # while training give only X_test not y_test
y_pred
# Out:
# array([3.21008706, 3.27850806, 3.29060689, 3.35735908, 3.31271855,
#        3.17879697, 3.30437453, 3.37571593, 3.23887394, 3.23637074,
#        3.27308444, 3.27683925, 3.35026666, 3.2931101 , 3.24388036,
#        3.30896374, 3.36695471, 3.31981097, 3.23678794, 3.1879754 ,
#        3.2580652 , 3.32440019, 3.27266724, 3.21759668, 3.19131301,
#        3.35443867, 3.18130018, 3.32481739, 3.21259027, 3.26974683,
#        3.33357861, 3.2217687 , 3.2242719 , 3.25222438, 3.3277378 ,
#        3.32147978, 3.30228852, 3.35902789, 3.31897657, 3.27183284,
#        3.30687774, 3.19173021, 3.33983663, 3.26474042, 3.20424625,
#        3.17295616, 3.26140281, 3.36737191, 3.34609465, 3.21509348,
#        3.32314858, 3.24346316, 3.33524742, 3.23261593, 3.22760951,
#        3.17754537, 3.30854654, 3.24471476, 3.26599202, 3.31438736,
#        3.20508065, 3.28768648, 3.33316141, 3.36069669, 3.29811651,
#        3.25431039, 3.17671097, 3.34025383, 3.28560048, 3.20382904,
# ...

# %%
# Visualising the training set results
plt.scatter(X_train,y_train,color='green') # train data in green line # y_train is y hat
plt.scatter(X_test,y_test,color='red') # test data in red line
plt.plot(X_train,regressor.predict(X_train),color='blue') # gives o/p of y hat. from  traning I have to predict the value ie LR line
plt.title ('Salary vs Experience (Training set)')
plt.xlabel ('year of Experience')
plt.ylabel ('Salary')

plt.show()
